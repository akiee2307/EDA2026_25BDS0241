# %%
import os
print(os.getcwd())
# Out:
# /Users/sohamm

# %%
import pandas as pd
data = pd.read_csv("/Users/sohamm/Downloads/eda1.csv") 
print(data)
# Out:
#    Employee ID             Name   Department  Age  Experience  Salary
# 0         E001     Aarav Sharma  Engineering   29           4   72000
# 1         E002       Priya Nair    Marketing   34           9   65000
# 2         E003      Rohan Mehta        Sales   41          15   58000
# 3         E004     Sneha Kapoor           HR   26           2   48000
# 4         E005       Vikram Rao  Engineering   38          12   95000
# 5         E006      Ananya Iyer      Finance   31           6   70000
# 6         E007   Karan Malhotra        Sales   45          18   62000
# 7         E008      Divya Menon  Engineering   27           3   68000
# 8         E009      Arjun Reddy    Marketing   36          10   73000
# 9         E010      Ishita Bose           HR   23           1   42000
# 10        E011  Aditya Kulkarni      Finance   40          14   88000
# 11        E012     Meera Pillai  Engineering   33           7   79000
# ...

# %%
print(data.head())      
print(data.tail())      
print(data.shape)
# Out:
#   Employee ID          Name   Department  Age  Experience  Salary
# 0        E001  Aarav Sharma  Engineering   29           4   72000
# 1        E002    Priya Nair    Marketing   34           9   65000
# 2        E003   Rohan Mehta        Sales   41          15   58000
# 3        E004  Sneha Kapoor           HR   26           2   48000
# 4        E005    Vikram Rao  Engineering   38          12   95000
#    Employee ID           Name   Department  Age  Experience  Salary
# 15        E016     Neha Gupta      Finance   35           8   76000
# 16        E017   Aryan Chopra           HR   30           5   52000
# 17        E018    Tanya Bhatt        Sales   22           1   40000
# 18        E019   Rohit Saxena  Engineering   31           6   74000
# 19        E020  Pooja Agarwal    Marketing   28           4   61000
# (20, 6)

# %%
# 1. Column names
print(data.columns)

# 2. Data types of each column
print(data.dtypes)

# 3. Metadata via info()
data.info()

# 4. Descriptive statistics
print(data.describe())
# Out:
# Index(['Employee ID', 'Name', 'Department', 'Age', 'Experience', 'Salary'], dtype='str')
# Employee ID      str
# Name             str
# Department       str
# Age            int64
# Experience     int64
# Salary         int64
# dtype: object
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee ID  20 non-null     str
#  1   Name         20 non-null     str
#  2   Department   20 non-null     str
#  3   Age          20 non-null     int64
#  4   Experience   20 non-null     int64
#  5   Salary       20 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 1.1 KB
#              Age  Experience         Salary
# count  20.000000   20.000000      20.000000
# mean   32.450000    7.550000   66250.000000
# std     7.059708    5.679835   17010.445707
# min    22.000000    1.000000   40000.000000
# 25%    27.750000    3.750000   54250.000000
# ...

# %%
import pandas as pd
data = pd.read_csv("/Users/sohamm/Downloads/eda1.csv") 
# 1. Count missing values in each column
missing_counts = data.isnull().sum()
print(missing_counts)

# 2. Percentage of missing values
missing_percent = (data.isnull().sum() / len(data)) * 100
print(missing_percent)

# 3. Columns with highest number of missing entries, ranked
missing_sorted = missing_counts.sort_values(ascending=False)
print(missing_sorted)
# Out:
# Employee ID    0
# Name           0
# Department     0
# Age            0
# Experience     0
# Salary         0
# dtype: int64
# Employee ID    0.0
# Name           0.0
# Department     0.0
# Age            0.0
# Experience     0.0
# Salary         0.0
# dtype: float64
# Employee ID    0
# Name           0
# Department     0
# Age            0
# Experience     0
# Salary         0
# dtype: int64
